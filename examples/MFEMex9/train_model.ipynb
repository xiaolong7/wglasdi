# %%
import sys
sys.path.append("../../src")
import os
import datetime
import pandas as pd
import numpy as np
from sindy_utils import library_size
from training_wsindy import train_network
from error_utils import *
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_v2_behavior()
from time import time
import matplotlib.pyplot as plt
import pickle 
import subprocess as sp
from matplotlib.ticker import FormatStrFormatter
# Out:
# WARNING:tensorflow:From /g/g92/he10/.conda/envs/tfvenv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def get_gpu_memory():
  _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]

  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"
  memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
  memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
  return memory_free_values

device_list = tf.config.list_physical_devices('GPU')
free_mem = get_gpu_memory()
for i,gpu in enumerate(device_list):
    print(f'{gpu}: free memory: {free_mem[i]}')
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): free memory: 13863
# PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'): free memory: 15192
# PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'): free memory: 16125
# PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'): free memory: 13373

# %%
# specify which GPU to use
config = tf.ConfigProto(log_device_placement=False, gpu_options=tf.GPUOptions(allow_growth=True,
                                                                              visible_device_list='1'))

# %% [markdown]
# ## Load data

# %%
# load initial training dataset
p1_train = np.array([1.5]) # w1 of initial condition
p2_train = np.array([2.0]) # w2 of initial condition
num_train = p1_train.size * p2_train.size  # initial number of training data
tstop = 3
dt = 1e-2
train_data = pickle.load(open(f"/g/g92/he10/Research/data/MFEMex9/local{num_train}_p1{p1_train[0]}_p2{p2_train[0]}_tstop{tstop:.1f}.p", "rb"))
num_wsindy = len(train_data['data'])
input_dim = train_data['data'][0]['x'].shape[1]

for i in range(num_wsindy):
    print(f"case {i}: params: {train_data['param'][i]}, x shape: {train_data['data'][i]['x'].shape}")
    
# load dataset of discrete parameter space for greedy sampling
p1_test = np.array([1.5]) # w1 of initial condition
p2_test = np.array([2.0]) # w2 of initial condition
num_test = p1_test.size * p2_test.size # number of cases in the discrete parameter space
test_data = pickle.load(open(f"/g/g92/he10/Research/data/MFEMex9/local{num_test}_p1{p1_test[0]}_p2{p2_test[0]}_tstop{tstop:.1f}.p", "rb"))
# Out:
# case 0: params: [1.5 2. ], x shape: (301, 9216)

# %%
grid1, grid2 = np.meshgrid(p1_train, p2_train)
train_param = np.hstack((grid1.flatten().reshape(-1,1), grid2.flatten().reshape(-1,1)))
grid1, grid2 = np.meshgrid(p1_test, p2_test)
test_param = np.hstack((grid1.flatten().reshape(-1,1), grid2.flatten().reshape(-1,1)))

train_idx = []
for i in range(num_test):
    for j in range(num_train):
        if np.abs(test_param[i,0]-train_param[j,0]) < 1e-8 and \
        np.abs(test_param[i,1]-train_param[j,1]) < 1e-8:
            train_idx.append(i)
print(train_idx)
# Out:
# [0]

# %% [markdown]
# ## Set up model and training parameters

# %%
params = {}

params['seed'] = 1 # random seed
params['config'] = config
params['num_wsindy'] = num_wsindy
params['param'] = train_data['param']
params['train_idx'] = train_idx
params['input_dim'] = input_dim
params['latent_dim'] = 3
params['poly_order'] = 1
params['include_sine'] = False
params['include_cosine'] = False
params['include_costant'] = True
params['library_dim'] = library_size(params['latent_dim'], params['poly_order'], 
                                     params['include_sine'], params['include_cosine'], 
                                     params['include_costant'])

# sequential thresholding parameters
params['sequential_thresholding'] = False
params['coefficient_threshold'] = 0.1
params['threshold_frequency'] = 500
params['coefficient_mask'] = np.ones((params['library_dim'], params['latent_dim']))
params['coefficient_initialization'] = 'constant'

# loss function weighting
params['loss_weight_decoder'] = 1.0
params['loss_weight_wsindy_x'] = 1
params['loss_weight_wsindy_z'] = 1
params['loss_weight_wsindy_regularization'] = 1e-4
params['diff'] = 'symb' # 'symb': symbolic diff (only for fully connected Autoencoder), 'auto': automatic diff
params['activation'] = 'relu'
params['widths'] = [100]

# training parameters
params['L'] = 10
params['epoch_size'] = train_data['data'][0]['x'].shape[0]
num_batch = 1
params['batch_size'] = (params['epoch_size'] + 2 * (num_batch-1) * params['L']) // num_batch # for N batches: (epoch_size + 2*(N-1)*L)/N
params['batch_overlap'] = 2*params['L']
params['learning_rate'] = 1e-3

params['fig_path'] = os.getcwd() + '/fig/nDI1/'
if not os.path.exists(params['fig_path']):
    os.makedirs(params['fig_path'])
params['print_progress'] = True
params['print_frequency'] = 200
params['save_frequency'] = 10000

# training epochs
params['max_epochs'] = 30000  # max number of training epochs

# Greedy sampling algorithm
params['update_epoch'] = 30000 # Greedy sampling frequency
params['tol'] = 0.001          # initial tolerance of the maximum error indicator in the parameter space; it will be updated during training using the prescribed `adaptive` method
params['tol2'] = 5             # initial tolerance of the maximum relative error in the parameter space
params['wsindy_max'] = 25       # max number of local DIs; if tolerance is used as a termination criterior, set it as None
params['convex_knn'] = 1       # the number nearest local DIs used for convex interpolation during Greedy sampling
params['test_data'] = test_data # dataset of the discrete parameter space
params['test_param'] = np.hstack((p1_test.reshape(-1,1), p2_test.reshape(-1,1))) # parameters of the discrete parameter space
params['num_test'] = num_test  # the number of parameter cases of the discrete parameter space
params['coeff_exist'] = False  # whether to initialize model coefficients with pescribed values, set as False
params['retrain'] = False      # whether to retrain the model; set as False for training a new model

# Error indicator:
# 1: max relative error (if test data is available); 
# 2: residual norm for 1D Burgers eqn; 
# 3: residual norm for 2D Burgers eqn; 
# 4: residual norm for time dependent heat conduction (MFEM example 16); 
# 5: residual norm for radial advection (MFEM example 9)
params['err_type'] = 5                            
params['subsize'] = int(0.3 * num_test) # initial random subset size, the number of randomly selected cases for Greedy sampling
params['subsize_max'] = 50              # maximum random subset size in percentage

# Adaptive approach for tol of error indicator:
# 'mean': use mean ratios between error indicator and max relative errors
# 'reg_mean': use linear regression line
# 'reg_max': use linear regression line shifted by std to upper bound
# 'reg_min': use linear regression line shifted by std to lower bound, more conservative
params['adaptive'] = 'reg_max'                      

# PDE parameters
params['pde'] = {}
params['pde']['exe_file'] = '../../src/ex9'
params['pde']['m_file'] = './periodic-square.mesh'
params['pde']['u_file'] = './ex9-u_pred1.gf'
params['pde']['res_file'] = "./ex9-residual1.gf"
params['pde']['prob'] = 3
params['pde']['rl'] = 4
params['pde']['order'] = 1
params['pde']['tstop'] = tstop
params['pde']['dt'] = dt
params['pde']['res_ns'] = 0.1 # percentage of time steps for residual evaluation
params['pde']['Mmax_iter'] = 20 # max iterations in Tsolver

# %%
if params['retrain']:
    save_name = 'ex9_2022_11_20_16_45_41'
    params = pickle.load(open(params['fig_path'] + save_name + '_params.pkl', 'rb'))
    params['retrain'] = True
    params['coeff_exist'] = True  # flag to indicate whether to initialize model coefficients with pescribed values
    params['save_name'] = save_name
    params['max_epochs'] = 600000
    params['update_epoch'] = 20000
    params['save_frequency'] = 500
    
    for i in params['train_idx'][4:]:
        train_data['data'].append(test_data['data'][i])
        train_data['param'].append(test_data['param'][i])

# %% [markdown]
# ## Training

# %%
df = pd.DataFrame()
timer = []
timer.append(time())

if not params['retrain']:
    params['save_name'] = 'ex9_' + datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
tf.reset_default_graph()
results_dict = train_network(train_data, params)
df = df.append({**results_dict, **params}, ignore_index=True)
    
timer.append(time())
print(f'training time: {(timer[-1]-timer[0])/60:.2f} mins, {(timer[-1]-timer[0])/3600:.2f} hours')
# Out:
# WARNING:tensorflow:From ../../src/autoencoder_wsindy.py:531: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# * Evaluating
#   Time: 8.12 s, Case: [1.5 2. ], Tol: 0.00100, Max Error: 0.367827
# Epoch 0
#   train loss: 3.6177e-01, decoder: 2.6395e-01, wsindy-x: 9.7306e-05, wsindy-z: 9.7632e-02, wsindy-reg: 0.9997
# Epoch 200
#   train loss: 1.1880e-03, decoder: 7.8011e-04, wsindy-x: 1.0660e-05, wsindy-z: 2.9797e-04, wsindy-reg: 0.9923
# Epoch 400
#   train loss: 3.7134e-04, decoder: 1.9446e-04, wsindy-x: 4.3961e-06, wsindy-z: 7.3474e-05, wsindy-reg: 0.9902
# Epoch 600
#   train loss: 2.1981e-04, decoder: 9.1951e-05, wsindy-x: 2.4169e-06, wsindy-z: 2.6665e-05, wsindy-reg: 0.9878
# Epoch 800
#   train loss: 1.5985e-04, decoder: 4.7754e-05, wsindy-x: 1.5825e-06, wsindy-z: 1.2045e-05, wsindy-reg: 0.9847
# Epoch 1000
#   train loss: 1.3904e-04, decoder: 3.1721e-05, wsindy-x: 1.1364e-06, wsindy-z: 8.0332e-06, wsindy-reg: 0.9815
# Epoch 1200
#   train loss: 1.2049e-04, decoder: 1.7024e-05, wsindy-x: 8.9597e-07, wsindy-z: 4.8356e-06, wsindy-reg: 0.9774
# Epoch 1400
#   train loss: 1.1462e-04, decoder: 1.3451e-05, wsindy-x: 7.5858e-07, wsindy-z: 3.1566e-06, wsindy-reg: 0.9726
# Epoch 1600
#   train loss: 1.4769e-04, decoder: 4.2326e-05, wsindy-x: 7.2905e-07, wsindy-z: 7.9259e-06, wsindy-reg: 0.9671
# Epoch 1800
#   train loss: 1.6269e-04, decoder: 6.1665e-05, wsindy-x: 6.6811e-07, wsindy-z: 4.2325e-06, wsindy-reg: 0.9612
# Epoch 2000
#   train loss: 1.3817e-04, decoder: 3.6879e-05, wsindy-x: 6.3838e-07, wsindy-z: 5.1898e-06, wsindy-reg: 0.9546
# Epoch 2200
#   train loss: 1.5207e-04, decoder: 5.3952e-05, wsindy-x: 5.8651e-07, wsindy-z: 2.7942e-06, wsindy-reg: 0.9474
# Epoch 2400
#   train loss: 1.6935e-04, decoder: 7.1921e-05, wsindy-x: 5.7503e-07, wsindy-z: 2.9493e-06, wsindy-reg: 0.9391
# Epoch 2600
#   train loss: 1.0836e-04, decoder: 1.2399e-05, wsindy-x: 5.3936e-07, wsindy-z: 2.4086e-06, wsindy-reg: 0.9301
# Epoch 2800
#   train loss: 1.0249e-04, decoder: 6.7990e-06, wsindy-x: 5.1372e-07, wsindy-z: 3.1858e-06, wsindy-reg: 0.9199
# Epoch 3000
#   train loss: 9.9742e-05, decoder: 5.7835e-06, wsindy-x: 4.9750e-07, wsindy-z: 2.6070e-06, wsindy-reg: 0.9085
# Epoch 3200
#   train loss: 7.9591e-04, decoder: 6.8614e-04, wsindy-x: 8.5340e-07, wsindy-z: 1.9287e-05, wsindy-reg: 0.8963
# Epoch 3400
#   train loss: 2.6827e-04, decoder: 1.7396e-04, wsindy-x: 4.7934e-07, wsindy-z: 5.5545e-06, wsindy-reg: 0.8828
# Epoch 3600
#   train loss: 9.2204e-05, decoder: 2.9384e-06, wsindy-x: 4.4445e-07, wsindy-z: 1.9492e-06, wsindy-reg: 0.8687
# Epoch 3800
#   train loss: 9.0935e-05, decoder: 3.9051e-06, wsindy-x: 4.3199e-07, wsindy-z: 1.2568e-06, wsindy-reg: 0.8534
# Epoch 4000
#   train loss: 1.0743e-04, decoder: 2.0600e-05, wsindy-x: 4.1927e-07, wsindy-z: 2.7836e-06, wsindy-reg: 0.8363
# Epoch 4200
#   train loss: 1.4071e-04, decoder: 5.6410e-05, wsindy-x: 4.1646e-07, wsindy-z: 2.1247e-06, wsindy-reg: 0.8176
# Epoch 4400
#   train loss: 8.4675e-05, decoder: 2.6129e-06, wsindy-x: 4.0216e-07, wsindy-z: 1.9807e-06, wsindy-reg: 0.7968
# Epoch 4600
#   train loss: 1.1036e-04, decoder: 2.7657e-05, wsindy-x: 3.9428e-07, wsindy-z: 4.8418e-06, wsindy-reg: 0.7747
# Epoch 4800
#   train loss: 8.2531e-05, decoder: 3.9755e-06, wsindy-x: 3.7894e-07, wsindy-z: 3.1434e-06, wsindy-reg: 0.7503
# Epoch 5000
#   train loss: 8.7793e-05, decoder: 1.1127e-05, wsindy-x: 3.6781e-07, wsindy-z: 3.8757e-06, wsindy-reg: 0.7242
# Epoch 5200
#   train loss: 8.1186e-05, decoder: 8.1824e-06, wsindy-x: 3.5742e-07, wsindy-z: 3.0249e-06, wsindy-reg: 0.6962
# Epoch 5400
#   train loss: 7.3139e-05, decoder: 2.6053e-06, wsindy-x: 3.4403e-07, wsindy-z: 3.5940e-06, wsindy-reg: 0.6660
# Epoch 5600
#   train loss: 6.9001e-05, decoder: 2.2606e-06, wsindy-x: 3.3014e-07, wsindy-z: 2.9238e-06, wsindy-reg: 0.6349
# Epoch 5800
#   train loss: 7.0150e-05, decoder: 5.8596e-06, wsindy-x: 3.2591e-07, wsindy-z: 3.0724e-06, wsindy-reg: 0.6089
# Epoch 6000
#   train loss: 6.8365e-05, decoder: 3.5158e-06, wsindy-x: 3.1419e-07, wsindy-z: 5.8577e-06, wsindy-reg: 0.5868
# Epoch 6200
#   train loss: 1.0016e-04, decoder: 3.4013e-05, wsindy-x: 3.2603e-07, wsindy-z: 9.0704e-06, wsindy-reg: 0.5675
# Epoch 6400
#   train loss: 6.0546e-05, decoder: 2.9019e-06, wsindy-x: 3.0796e-07, wsindy-z: 2.1450e-06, wsindy-reg: 0.5519
# Epoch 6600
#   train loss: 6.6298e-05, decoder: 8.6539e-06, wsindy-x: 2.9100e-07, wsindy-z: 3.7834e-06, wsindy-reg: 0.5357
# Epoch 6800
#   train loss: 8.8309e-05, decoder: 2.5222e-05, wsindy-x: 2.9632e-07, wsindy-z: 1.1023e-05, wsindy-reg: 0.5177
# Epoch 7000
#   train loss: 6.8299e-05, decoder: 1.3810e-05, wsindy-x: 2.8701e-07, wsindy-z: 4.3766e-06, wsindy-reg: 0.4982
# Epoch 7200
#   train loss: 5.3203e-05, decoder: 2.5126e-06, wsindy-x: 2.8531e-07, wsindy-z: 2.6208e-06, wsindy-reg: 0.4778
# Epoch 7400
#   train loss: 5.0754e-05, decoder: 2.4068e-06, wsindy-x: 2.8753e-07, wsindy-z: 2.3578e-06, wsindy-reg: 0.4570
# Epoch 7600
#   train loss: 5.3490e-05, decoder: 4.5595e-06, wsindy-x: 2.8853e-07, wsindy-z: 5.0188e-06, wsindy-reg: 0.4362
# Epoch 7800
#   train loss: 5.8961e-05, decoder: 1.2028e-05, wsindy-x: 2.8633e-07, wsindy-z: 5.2920e-06, wsindy-reg: 0.4135
# Epoch 8000
#   train loss: 5.7614e-05, decoder: 1.2100e-05, wsindy-x: 2.8261e-07, wsindy-z: 5.8692e-06, wsindy-reg: 0.3936
# Epoch 8200
#   train loss: 9.0295e-05, decoder: 4.5389e-05, wsindy-x: 2.8104e-07, wsindy-z: 7.0678e-06, wsindy-reg: 0.3756
# Epoch 8400
#   train loss: 2.3847e-04, decoder: 1.8805e-04, wsindy-x: 2.9685e-07, wsindy-z: 1.4396e-05, wsindy-reg: 0.3573
# Epoch 8600
#   train loss: 5.6329e-05, decoder: 1.7540e-05, wsindy-x: 2.6037e-07, wsindy-z: 4.6090e-06, wsindy-reg: 0.3392
# Epoch 8800
#   train loss: 1.2292e-04, decoder: 8.0231e-05, wsindy-x: 2.6323e-07, wsindy-z: 1.0337e-05, wsindy-reg: 0.3209
# Epoch 9000
#   train loss: 4.3309e-05, decoder: 6.9310e-06, wsindy-x: 2.5755e-07, wsindy-z: 6.0381e-06, wsindy-reg: 0.3008
# Epoch 9200
#   train loss: 4.6000e-05, decoder: 1.3090e-05, wsindy-x: 2.5287e-07, wsindy-z: 4.7138e-06, wsindy-reg: 0.2794
# Epoch 9400
#   train loss: 3.7493e-05, decoder: 5.4063e-06, wsindy-x: 2.4997e-07, wsindy-z: 6.1446e-06, wsindy-reg: 0.2569
# Epoch 9600
#   train loss: 3.5663e-05, decoder: 8.8254e-06, wsindy-x: 2.5041e-07, wsindy-z: 3.2079e-06, wsindy-reg: 0.2338
# Epoch 9800
#   train loss: 3.0133e-05, decoder: 6.3317e-06, wsindy-x: 2.4516e-07, wsindy-z: 2.5559e-06, wsindy-reg: 0.2100
# Epoch 10000
#   train loss: 2.7495e-05, decoder: 5.5935e-06, wsindy-x: 2.4035e-07, wsindy-z: 3.0534e-06, wsindy-reg: 0.1861
# Epoch 10200
#   train loss: 2.6711e-05, decoder: 6.4016e-06, wsindy-x: 2.4136e-07, wsindy-z: 3.9645e-06, wsindy-reg: 0.1610
# Epoch 10400
#   train loss: 2.0458e-05, decoder: 3.4041e-06, wsindy-x: 2.3828e-07, wsindy-z: 3.1938e-06, wsindy-reg: 0.1362
# Epoch 10600
#   train loss: 2.7519e-05, decoder: 1.3716e-05, wsindy-x: 2.4150e-07, wsindy-z: 2.5069e-06, wsindy-reg: 0.1105
# Epoch 10800
#   train loss: 2.5184e-05, decoder: 1.2492e-05, wsindy-x: 2.3855e-07, wsindy-z: 3.9075e-06, wsindy-reg: 0.0855
# Epoch 11000
#   train loss: 4.1138e-05, decoder: 3.1193e-05, wsindy-x: 2.4418e-07, wsindy-z: 3.4294e-06, wsindy-reg: 0.0627
# Epoch 11200
#   train loss: 3.6618e-05, decoder: 2.7001e-05, wsindy-x: 2.4850e-07, wsindy-z: 4.0674e-06, wsindy-reg: 0.0530
# Epoch 11400
#   train loss: 1.3414e-05, decoder: 4.9374e-06, wsindy-x: 2.4071e-07, wsindy-z: 2.8856e-06, wsindy-reg: 0.0535
# Epoch 11600
#   train loss: 2.4545e-05, decoder: 1.4477e-05, wsindy-x: 2.3775e-07, wsindy-z: 4.5404e-06, wsindy-reg: 0.0529
# Epoch 11800
#   train loss: 1.5588e-05, decoder: 8.2205e-06, wsindy-x: 2.3859e-07, wsindy-z: 1.9688e-06, wsindy-reg: 0.0516
# Epoch 12000
#   train loss: 2.2500e-05, decoder: 1.5571e-05, wsindy-x: 2.3983e-07, wsindy-z: 1.7121e-06, wsindy-reg: 0.0498
# Epoch 12200
#   train loss: 2.2488e-05, decoder: 1.6324e-05, wsindy-x: 2.3914e-07, wsindy-z: 1.1322e-06, wsindy-reg: 0.0479
# Epoch 12400
#   train loss: 7.6915e-06, decoder: 9.1838e-07, wsindy-x: 2.4193e-07, wsindy-z: 1.9163e-06, wsindy-reg: 0.0461
# Epoch 12600
#   train loss: 7.5648e-06, decoder: 1.0962e-06, wsindy-x: 2.4356e-07, wsindy-z: 1.9989e-06, wsindy-reg: 0.0423
# Epoch 12800
#   train loss: 1.1865e-05, decoder: 5.7939e-06, wsindy-x: 2.4413e-07, wsindy-z: 1.9249e-06, wsindy-reg: 0.0390
# Epoch 13000
#   train loss: 6.0913e-06, decoder: 9.2767e-07, wsindy-x: 2.6128e-07, wsindy-z: 1.3100e-06, wsindy-reg: 0.0359
# Epoch 13200
#   train loss: 4.3588e-05, decoder: 3.8631e-05, wsindy-x: 2.5639e-07, wsindy-z: 1.5040e-06, wsindy-reg: 0.0320
# Epoch 13400
#   train loss: 5.3964e-06, decoder: 1.2146e-06, wsindy-x: 2.5342e-07, wsindy-z: 1.0418e-06, wsindy-reg: 0.0289
# Epoch 13600
#   train loss: 1.2443e-05, decoder: 8.9293e-06, wsindy-x: 2.5080e-07, wsindy-z: 6.2585e-07, wsindy-reg: 0.0264
# Epoch 13800
#   train loss: 7.2474e-06, decoder: 3.8546e-06, wsindy-x: 2.5361e-07, wsindy-z: 5.8364e-07, wsindy-reg: 0.0256
# Epoch 14000
#   train loss: 6.0997e-06, decoder: 2.8610e-06, wsindy-x: 2.5111e-07, wsindy-z: 4.8040e-07, wsindy-reg: 0.0251
# Epoch 14200
#   train loss: 4.6100e-06, decoder: 1.3242e-06, wsindy-x: 2.4989e-07, wsindy-z: 5.5035e-07, wsindy-reg: 0.0249
# Epoch 14400
#   train loss: 1.6654e-05, decoder: 1.3131e-05, wsindy-x: 2.5432e-07, wsindy-z: 7.9841e-07, wsindy-reg: 0.0247
# Epoch 14600
#   train loss: 3.9734e-06, decoder: 7.4486e-07, wsindy-x: 2.4995e-07, wsindy-z: 5.5704e-07, wsindy-reg: 0.0242
# Epoch 14800
#   train loss: 1.0274e-04, decoder: 9.8790e-05, wsindy-x: 2.5884e-07, wsindy-z: 1.2966e-06, wsindy-reg: 0.0239
# Epoch 15000
#   train loss: 5.8241e-06, decoder: 2.1863e-06, wsindy-x: 2.5342e-07, wsindy-z: 1.0186e-06, wsindy-reg: 0.0237
# Epoch 15200
#   train loss: 5.0810e-06, decoder: 1.6383e-06, wsindy-x: 2.5570e-07, wsindy-z: 8.4855e-07, wsindy-reg: 0.0234
# Epoch 15400
#   train loss: 7.1060e-06, decoder: 3.2254e-06, wsindy-x: 2.5656e-07, wsindy-z: 1.3243e-06, wsindy-reg: 0.0230
# Epoch 15600
#   train loss: 9.2615e-06, decoder: 5.4719e-06, wsindy-x: 2.5930e-07, wsindy-z: 1.2543e-06, wsindy-reg: 0.0228
# Epoch 15800
#   train loss: 4.4087e-06, decoder: 8.7619e-07, wsindy-x: 2.5750e-07, wsindy-z: 1.0295e-06, wsindy-reg: 0.0225
# Epoch 16000
#   train loss: 4.1363e-06, decoder: 8.9631e-07, wsindy-x: 2.5722e-07, wsindy-z: 7.7233e-07, wsindy-reg: 0.0221
# Epoch 16200
#   train loss: 1.2793e-05, decoder: 8.3665e-06, wsindy-x: 2.5910e-07, wsindy-z: 1.9832e-06, wsindy-reg: 0.0218
# Epoch 16400
#   train loss: 4.8025e-06, decoder: 1.7555e-06, wsindy-x: 2.5849e-07, wsindy-z: 6.3449e-07, wsindy-reg: 0.0215
# Epoch 16600
#   train loss: 5.6962e-06, decoder: 2.3558e-06, wsindy-x: 2.5887e-07, wsindy-z: 9.4853e-07, wsindy-reg: 0.0213
# Epoch 16800
#   train loss: 9.6652e-06, decoder: 6.0688e-06, wsindy-x: 2.5763e-07, wsindy-z: 1.2361e-06, wsindy-reg: 0.0210
# Epoch 17000
#   train loss: 9.0108e-06, decoder: 5.7335e-06, wsindy-x: 2.5902e-07, wsindy-z: 9.3266e-07, wsindy-reg: 0.0209
# Epoch 17200
#   train loss: 4.9733e-06, decoder: 1.9858e-06, wsindy-x: 2.5576e-07, wsindy-z: 6.8223e-07, wsindy-reg: 0.0205
# Epoch 17400
#   train loss: 4.9430e-06, decoder: 1.8190e-06, wsindy-x: 2.5440e-07, wsindy-z: 8.3373e-07, wsindy-reg: 0.0204
# Epoch 17600
#   train loss: 5.3709e-06, decoder: 2.5689e-06, wsindy-x: 2.4879e-07, wsindy-z: 5.3341e-07, wsindy-reg: 0.0202
# Epoch 17800
#   train loss: 5.3640e-06, decoder: 2.4890e-06, wsindy-x: 2.4665e-07, wsindy-z: 6.0854e-07, wsindy-reg: 0.0202
# Epoch 18000
#   train loss: 1.3892e-05, decoder: 1.0609e-05, wsindy-x: 2.4652e-07, wsindy-z: 1.0162e-06, wsindy-reg: 0.0202
# Epoch 18200
#   train loss: 5.7058e-06, decoder: 2.9400e-06, wsindy-x: 2.4054e-07, wsindy-z: 5.2911e-07, wsindy-reg: 0.0200
# Epoch 18400
#   train loss: 9.8335e-06, decoder: 7.0628e-06, wsindy-x: 2.4250e-07, wsindy-z: 5.2670e-07, wsindy-reg: 0.0200
# Epoch 18600
#   train loss: 3.9080e-06, decoder: 1.4232e-06, wsindy-x: 2.3617e-07, wsindy-z: 2.6407e-07, wsindy-reg: 0.0198
# Epoch 18800
#   train loss: 2.0903e-05, decoder: 1.8316e-05, wsindy-x: 2.4083e-07, wsindy-z: 3.6850e-07, wsindy-reg: 0.0198
# Epoch 19000
#   train loss: 3.7143e-06, decoder: 1.0492e-06, wsindy-x: 2.3594e-07, wsindy-z: 4.4824e-07, wsindy-reg: 0.0198
# Epoch 19200
#   train loss: 4.7787e-06, decoder: 2.3041e-06, wsindy-x: 2.3303e-07, wsindy-z: 2.6675e-07, wsindy-reg: 0.0197
# Epoch 19400
#   train loss: 6.3067e-06, decoder: 3.9042e-06, wsindy-x: 2.3167e-07, wsindy-z: 2.1121e-07, wsindy-reg: 0.0196
# Epoch 19600
#   train loss: 2.9697e-06, decoder: 6.3854e-07, wsindy-x: 2.2924e-07, wsindy-z: 1.4273e-07, wsindy-reg: 0.0196
# Epoch 19800
#   train loss: 3.3608e-06, decoder: 1.0487e-06, wsindy-x: 2.2798e-07, wsindy-z: 1.2555e-07, wsindy-reg: 0.0196
# Epoch 20000
#   train loss: 5.0292e-06, decoder: 2.7469e-06, wsindy-x: 2.2757e-07, wsindy-z: 1.1048e-07, wsindy-reg: 0.0194
# Epoch 20200
#   train loss: 8.2114e-06, decoder: 5.8736e-06, wsindy-x: 2.2956e-07, wsindy-z: 1.5272e-07, wsindy-reg: 0.0196
# Epoch 20400
#   train loss: 5.4439e-06, decoder: 3.1626e-06, wsindy-x: 2.2741e-07, wsindy-z: 1.0352e-07, wsindy-reg: 0.0195
# Epoch 20600
#   train loss: 3.1254e-06, decoder: 8.5499e-07, wsindy-x: 2.2620e-07, wsindy-z: 9.4244e-08, wsindy-reg: 0.0195
# Epoch 20800
#   train loss: 2.2821e-05, decoder: 2.0503e-05, wsindy-x: 2.2595e-07, wsindy-z: 1.4472e-07, wsindy-reg: 0.0195
# Epoch 21000
#   train loss: 1.8869e-05, decoder: 1.6559e-05, wsindy-x: 2.2620e-07, wsindy-z: 1.2582e-07, wsindy-reg: 0.0196
# Epoch 21200
#   train loss: 2.7873e-06, decoder: 5.5754e-07, wsindy-x: 2.2125e-07, wsindy-z: 8.1080e-08, wsindy-reg: 0.0193
# Epoch 21400
#   train loss: 3.1267e-06, decoder: 8.9415e-07, wsindy-x: 2.2090e-07, wsindy-z: 8.2361e-08, wsindy-reg: 0.0193
# Epoch 21600
#   train loss: 4.9968e-06, decoder: 2.7702e-06, wsindy-x: 2.1921e-07, wsindy-z: 7.7250e-08, wsindy-reg: 0.0193
# Epoch 21800
#   train loss: 1.1000e-05, decoder: 8.7736e-06, wsindy-x: 2.1689e-07, wsindy-z: 9.0844e-08, wsindy-reg: 0.0192
# Epoch 22000
#   train loss: 3.5844e-06, decoder: 1.3800e-06, wsindy-x: 2.1371e-07, wsindy-z: 7.0904e-08, wsindy-reg: 0.0192
# Epoch 22200
#   train loss: 3.1028e-06, decoder: 8.9476e-07, wsindy-x: 2.1182e-07, wsindy-z: 8.0645e-08, wsindy-reg: 0.0192
# Epoch 22400
#   train loss: 3.0786e-06, decoder: 8.9141e-07, wsindy-x: 2.1033e-07, wsindy-z: 7.0991e-08, wsindy-reg: 0.0191
# Epoch 22600
#   train loss: 1.0468e-05, decoder: 8.2881e-06, wsindy-x: 2.1000e-07, wsindy-z: 7.0665e-08, wsindy-reg: 0.0190
# Epoch 22800
#   train loss: 2.7713e-06, decoder: 6.0556e-07, wsindy-x: 2.0496e-07, wsindy-z: 6.5237e-08, wsindy-reg: 0.0190
# Epoch 23000
#   train loss: 2.6609e-06, decoder: 5.0238e-07, wsindy-x: 2.0242e-07, wsindy-z: 6.2230e-08, wsindy-reg: 0.0189
# Epoch 23200
#   train loss: 6.6323e-06, decoder: 4.4530e-06, wsindy-x: 2.0339e-07, wsindy-z: 7.4244e-08, wsindy-reg: 0.0190
# Epoch 23400
#   train loss: 2.1780e-05, decoder: 1.9611e-05, wsindy-x: 2.0925e-07, wsindy-z: 6.6437e-08, wsindy-reg: 0.0189
# Epoch 23600
#   train loss: 2.5855e-06, decoder: 4.5438e-07, wsindy-x: 1.9673e-07, wsindy-z: 5.6691e-08, wsindy-reg: 0.0188
# Epoch 23800
#   train loss: 2.7054e-06, decoder: 5.7420e-07, wsindy-x: 1.9575e-07, wsindy-z: 5.7442e-08, wsindy-reg: 0.0188
# Epoch 24000
#   train loss: 2.8513e-06, decoder: 7.0795e-07, wsindy-x: 1.9616e-07, wsindy-z: 5.9432e-08, wsindy-reg: 0.0189
# Epoch 24200
#   train loss: 4.1026e-05, decoder: 3.8835e-05, wsindy-x: 2.0053e-07, wsindy-z: 1.2268e-07, wsindy-reg: 0.0187
# Epoch 24400
#   train loss: 2.5576e-06, decoder: 4.4071e-07, wsindy-x: 1.9174e-07, wsindy-z: 5.3606e-08, wsindy-reg: 0.0187
# Epoch 24600
#   train loss: 3.5973e-06, decoder: 1.4671e-06, wsindy-x: 1.9399e-07, wsindy-z: 5.9116e-08, wsindy-reg: 0.0188
# Epoch 24800
#   train loss: 8.2090e-06, decoder: 6.0820e-06, wsindy-x: 1.9300e-07, wsindy-z: 7.0825e-08, wsindy-reg: 0.0186
# Epoch 25000
#   train loss: 2.8685e-06, decoder: 7.6092e-07, wsindy-x: 1.8990e-07, wsindy-z: 5.5900e-08, wsindy-reg: 0.0186
# Epoch 25200
#   train loss: 2.7765e-06, decoder: 6.6801e-07, wsindy-x: 1.9114e-07, wsindy-z: 5.8152e-08, wsindy-reg: 0.0186
# Epoch 25400
#   train loss: 4.7801e-06, decoder: 2.6700e-06, wsindy-x: 1.9221e-07, wsindy-z: 6.5482e-08, wsindy-reg: 0.0185
# Epoch 25600
#   train loss: 5.1749e-06, decoder: 3.0867e-06, wsindy-x: 1.9009e-07, wsindy-z: 5.3319e-08, wsindy-reg: 0.0184
# Epoch 25800
#   train loss: 3.6260e-06, decoder: 1.5483e-06, wsindy-x: 1.8829e-07, wsindy-z: 4.7248e-08, wsindy-reg: 0.0184
# Epoch 26000
#   train loss: 2.7065e-06, decoder: 6.3695e-07, wsindy-x: 1.8744e-07, wsindy-z: 4.7780e-08, wsindy-reg: 0.0183
# Epoch 26200
#   train loss: 2.5487e-06, decoder: 4.7764e-07, wsindy-x: 1.8689e-07, wsindy-z: 4.6799e-08, wsindy-reg: 0.0184
# Epoch 26400
#   train loss: 2.4965e-06, decoder: 4.2831e-07, wsindy-x: 1.8730e-07, wsindy-z: 4.5921e-08, wsindy-reg: 0.0183
# Epoch 26600
#   train loss: 2.4604e-06, decoder: 4.0764e-07, wsindy-x: 1.8595e-07, wsindy-z: 4.4509e-08, wsindy-reg: 0.0182
# Epoch 26800
#   train loss: 2.4618e-06, decoder: 4.0496e-07, wsindy-x: 1.8677e-07, wsindy-z: 4.5945e-08, wsindy-reg: 0.0182
# Epoch 27000
#   train loss: 2.4322e-06, decoder: 3.8665e-07, wsindy-x: 1.8558e-07, wsindy-z: 4.2613e-08, wsindy-reg: 0.0182
# Epoch 27200
#   train loss: 2.4672e-06, decoder: 4.2534e-07, wsindy-x: 1.8535e-07, wsindy-z: 4.3085e-08, wsindy-reg: 0.0181
# Epoch 27400
#   train loss: 8.1898e-06, decoder: 6.1314e-06, wsindy-x: 1.8522e-07, wsindy-z: 5.8393e-08, wsindy-reg: 0.0181
# Epoch 27600
#   train loss: 5.7864e-06, decoder: 3.7376e-06, wsindy-x: 1.8665e-07, wsindy-z: 4.8776e-08, wsindy-reg: 0.0181
# Epoch 27800
#   train loss: 3.5379e-06, decoder: 1.4900e-06, wsindy-x: 1.8581e-07, wsindy-z: 4.5675e-08, wsindy-reg: 0.0182
# Epoch 28000
#   train loss: 1.2863e-05, decoder: 1.0778e-05, wsindy-x: 1.9170e-07, wsindy-z: 7.7409e-08, wsindy-reg: 0.0182
# Epoch 28200
#   train loss: 8.3632e-06, decoder: 6.2786e-06, wsindy-x: 1.9074e-07, wsindy-z: 8.4599e-08, wsindy-reg: 0.0181
# Epoch 28400
#   train loss: 2.0782e-05, decoder: 1.8661e-05, wsindy-x: 1.8917e-07, wsindy-z: 1.2599e-07, wsindy-reg: 0.0181
# Epoch 28600
#   train loss: 1.2219e-05, decoder: 1.0163e-05, wsindy-x: 1.8650e-07, wsindy-z: 6.8990e-08, wsindy-reg: 0.0180
# Epoch 28800
#   train loss: 2.9557e-06, decoder: 9.4067e-07, wsindy-x: 1.8321e-07, wsindy-z: 4.2021e-08, wsindy-reg: 0.0179
# Epoch 29000
#   train loss: 4.2036e-05, decoder: 3.9994e-05, wsindy-x: 1.9977e-07, wsindy-z: 6.5323e-08, wsindy-reg: 0.0178
# Epoch 29200
#   train loss: 4.5044e-06, decoder: 2.4713e-06, wsindy-x: 1.8504e-07, wsindy-z: 4.9641e-08, wsindy-reg: 0.0180
# Epoch 29400
#   train loss: 2.6026e-06, decoder: 6.0056e-07, wsindy-x: 1.8384e-07, wsindy-z: 3.9018e-08, wsindy-reg: 0.0178
# Epoch 29600
#   train loss: 3.2737e-06, decoder: 1.2742e-06, wsindy-x: 1.8353e-07, wsindy-z: 4.0956e-08, wsindy-reg: 0.0177
# Epoch 29800
#   train loss: 2.5060e-06, decoder: 5.0735e-07, wsindy-x: 1.8297e-07, wsindy-z: 3.9227e-08, wsindy-reg: 0.0178
# * Evaluating
#   Time: 2.80 s, Case: [1.5 2. ], Tol: 0.00100, Max Error: 0.022354
#   Max rel. err.: 1.5%, Update tolerance for error indicator from 0.00100 to 0.02235
#   PARAMETERS EXIST, NOT adding it! idx: 0 param: [1.5 2. ]
#   Max error indicator <= Tol! Current subset ratio 0.0%
# training time: 11.54 mins, 0.19 hours

# %%
# history of validation loss
train_loss = np.array(df['training_losses'][0]).squeeze()
test_loss = np.array(df['testing_losses'][0]).squeeze()

fig, ax1 = plt.subplots(figsize=(9,5))
xt = np.linspace(1,df['num_epochs'][0],train_loss.shape[0])
ax1.plot(xt, train_loss[:,0], 'r', label='Train')
ax1.set_yscale('log')
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
ax1.set_xlabel('Epochs', fontsize=16)
ax1.set_ylabel('Loss', color='r', fontsize=16)
ax1.set_xlim(0, df['num_epochs'][0])
ax1.tick_params(axis='x', labelsize=14)
ax1.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
xt = np.linspace(1,df['num_epochs'],test_loss.shape[0])
ax2.plot(xt, test_loss, 'b-o', label='Val')
ax2.set_ylabel('Max Error', color='b', fontsize=16)
ax2.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='y', labelcolor='b')

plt.grid()
plt.tight_layout()
plt.savefig(f"{params['fig_path']}/loss.png")

# %%
# remove *.gf temporary files for calculation of residual-based error indicator
import glob
files = glob.glob('*.gf')
subprocess.call(['rm', '-r'] + files)
# Out:
# 0
