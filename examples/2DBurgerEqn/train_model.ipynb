# %%
import sys
sys.path.append("../../src")
import os
import datetime
import pandas as pd
import numpy as np
from wsindy_utils import library_size
from training_wsindy import train_network
import tensorflow.compat.v1 as tf

tf.compat.v1.disable_v2_behavior()
from time import time
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import pickle 
import subprocess as sp
# Out:
# WARNING:tensorflow:From /g/g92/he10/.conda/envs/tfvenv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# specify which GPU to use
config = tf.ConfigProto(log_device_placement=False, gpu_options=tf.GPUOptions(allow_growth=True,
                                                                              visible_device_list='0'))

# %% [markdown]
# ## Load data

# %%
def preprocess_data(data, vel):
    for i in range(len(data['data'])):
        if vel == 1:
            data['data'][i]['x'] = data['data'][i].pop('u')
            data['data'][i]['dx'] = data['data'][i].pop('du')
            data['data'][i].pop('v')
            data['data'][i].pop('dv')
        elif vel == 2:
            data['data'][i]['x'] = data['data'][i].pop('v')
            data['data'][i]['dx'] = data['data'][i].pop('dv')
            data['data'][i].pop('u')
            data['data'][i].pop('du')
        elif vel == 3:
            data['data'][i]['x'] = np.hstack((data['data'][i]['u'], data['data'][i]['v']))
            data['data'][i]['dx'] = np.hstack((data['data'][i]['du'], data['data'][i]['dv']))
    return data

# %%
# load initial training dataset
vel = 3    # 1: u; 2: v; 3: u and v
option = 2 # 1: mean=0, std=1; 2: max=1; 3: [0,1]
Re = 10000
ic = 2     # initial condition, 1: Sine; 2: Gaussian
nx = 60
ny = nx
nt = 200
tstop = 1
amp_train =  np.array([0.7])
width_train =  np.array([0.9])

num_train = amp_train.size * width_train.size # initial number of training data
train_data_path = "/usr/workspace/he10/data/2DBurgerEqn/noisy/"
train_data = pickle.load(open(train_data_path + f"local{num_train}_Re{Re}_A0.70_W0.90_tstop{tstop:.1f}_nt{nt}_nx{nx}_10pc_noise.p", "rb"))
train_data = preprocess_data(train_data, vel)
num_wsindy = len(train_data['data'])
input_dim = train_data['data'][0]['x'].shape[1]

for i in range(num_wsindy):
    print(f"train case {i}: params: {train_data['param'][i]}, x shape: {train_data['data'][i]['x'].shape}")

# load dataset of discrete parameter space for greedy sampling
amp_test = np.array([0.7])
width_test =  np.array([0.9])
num_test = amp_test.size * width_test.size # number of cases in the discrete parameter space
test_data_path = "/usr/workspace/he10/data/2DBurgerEqn/"
test_data = pickle.load(open(test_data_path + f"local{num_test}_Re{Re}_A0.70_W0.90_tstop{tstop:.1f}_nt{nt}_nx{nx}.p", "rb"))
test_data = preprocess_data(test_data, vel)
# Out:
# train case 0: params: [0.7 0.9], x shape: (201, 7200)

# %%
grid1, grid2 = np.meshgrid(amp_train, width_train)
train_param = np.hstack((grid1.flatten().reshape(-1,1), grid2.flatten().reshape(-1,1)))
grid1, grid2 = np.meshgrid(amp_test, width_test)
test_param = np.hstack((grid1.flatten().reshape(-1,1), grid2.flatten().reshape(-1,1)))

train_idx = []
for i in range(num_test):
    for j in range(num_train):
        if np.abs(test_param[i,0]-train_param[j,0]) < 1e-8 and \
        np.abs(test_param[i,1]-train_param[j,1]) < 1e-8:
            train_idx.append(i)
print(train_idx)
# Out:
# [0]

# %% [markdown]
# ## Set up model and training parameters

# %%
params = {}
params['L'] = 10
params['seed'] = 1 # random seed
params['config'] = config
params['num_wsindy'] = num_wsindy
params['param'] = train_data['param']
params['train_idx'] = train_idx
params['input_dim'] = input_dim
params['latent_dim'] = 5
params['poly_order'] = 2
params['include_sine'] = False
params['include_cosine'] = False
params['include_costant'] = True
params['library_dim'] = library_size(params['latent_dim'], params['poly_order'], 
                                     params['include_sine'], params['include_cosine'], 
                                     params['include_costant'])

# sequential thresholding parameters
params['sequential_thresholding'] = False
params['coefficient_threshold'] = 0.1
params['threshold_frequency'] = 500
params['coefficient_mask'] = np.ones((params['library_dim'], params['latent_dim']))
params['coefficient_initialization'] = 'constant'

# loss function weighting
params['loss_weight_decoder'] = 1.0
params['loss_weight_wsindy_x'] = 10
params['loss_weight_wsindy_z'] = 10
params['loss_weight_wsindy_regularization'] = 1e-5
params['diff'] = 'symb' # 'symb': symbolic diff (only for fully connected Autoencoder), 'auto': automatic diff
params['activation'] = 'relu'
params['widths'] = [100]

# training parameters
params['epoch_size'] = train_data['data'][0]['x'].shape[0]
num_batch = 1
params['batch_size'] = (params['epoch_size'] + 2 * (num_batch-1) * params['L']) // num_batch # for N batches: (epoch_size + 2*(N-1)*L)/N
params['batch_overlap'] = 2*params['L']
params['learning_rate'] = 1e-4
params['fig_path'] =  os.getcwd() + '/fig/nDI1/'
if not os.path.exists(params['fig_path']):
    os.makedirs(params['fig_path'])
params['print_progress'] = True
params['print_frequency'] = 100
params['save_frequency'] = 10000

# training epochs
params['max_epochs'] = 10000

# Greedy sampling algorithm
params['update_epoch'] = 10000  # Greedy sampling frequency
params['tol'] = 0.02            # initial tolerance of the maximum error indicator in the parameter space; it will be updated during training using the prescribed `adaptive` method
params['tol2'] = 5              # initial tolerance of the maximum relative error in the parameter space
params['wsindy_max'] = 25       # max number of local DIs; if tolerance is used as a termination criterior, set it as None
params['convex_knn'] = 1        # the number nearest local DIs used for convex interpolation if used
params['test_data'] = test_data # dataset of the discrete parameter space
params['test_param'] = np.hstack((amp_test.reshape(-1,1), width_test.reshape(-1,1))) # parameters of the discrete parameter space
params['num_test'] = num_test   # the number of parameter cases of the discrete parameter space
params['coeff_exist'] = False   # whether to initialize model coefficients with pescribed values, set as False
params['retrain'] = False       # whether to retrain the model; set as False for training a new model

# Error indicator:
# 1: max relative error (if test data is available); 
# 2: residual norm for 1D Burgers eqn; 
# 3: residual norm for 2D Burgers eqn; 
# 4: residual norm for time dependent heat conduction (MFEM example 16); 
# 5: residual norm for radial advection (MFEM example 9)
params['err_type'] = 3                            
params['subsize'] = int(0.3 * num_test) # initial random subset size, the number of randomly selected cases for Greedy sampling
params['subsize_max'] = 50              # maximum random subset size in percentage

# Adaptive approach for tol of error indicator:
# 'mean': use mean ratios between error indicator and max relative errors
# 'reg_mean': use linear regression line
# 'reg_max': use linear regression line shifted by std to upper bound
# 'reg_min': use linear regression line shifted by std to lower bound, more conservative
params['adaptive'] = 'reg_max' 


# PDE parameters
params['pde'] = {}
params['pde']['Re'] = Re
params['pde']['nx'] = nx
params['pde']['nt'] = nt
params['pde']['tstop'] = tstop
params['pde']['ic'] = ic
params['pde']['dt'] = tstop / (nt-1)

# %%
if params['retrain']: # for retraining the model
    save_name = 'burger_2024_02_23_02_07_59'
    params = pickle.load(open(params['fig_path'] + save_name + '_params.pkl', 'rb'))
    params['retrain'] = True
    params['coeff_exist'] = True  # flag to indicate whether to initialize model coefficients with pescribed values
    params['save_name'] = save_name
    params['max_epochs'] = 100000
    params['update_epoch'] = 100000
    params['save_frequency'] = 5000
    # params['wsindy_max'] = 36       # max number of local DIs; if tolerance is used as a termination criterior, set it as None
    # num_batch = 4
    # params['batch_size'] = (params['epoch_size'] + 2 * (num_batch-1) * params['L']) // num_batch # for N batches: (epoch_size + 2*(N-1)*L)/N
    params['testing_losses'] = []
    
    for i in params['train_idx'][4:]:
        train_data['data'].append(test_data['data'][i])
        train_data['param'].append(test_data['param'][i])

# %% [markdown]
# ## Training

# %%
df = pd.DataFrame()
timer = []
timer.append(time())

if not params['retrain']:
    params['save_name'] = 'burger_' + datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
tf.reset_default_graph()
results_dict = train_network(train_data, params)
df = df.append({**results_dict, **params}, ignore_index=True)
    
timer.append(time())
print(f'training time: {(timer[-1]-timer[0])/60:.2f} mins, {(timer[-1]-timer[0])/3600:.2f} hours')
# Out:
# WARNING:tensorflow:From ../../src/autoencoder_wsindy.py:531: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# * Evaluating
# /g/g92/he10/.conda/envs/tfvenv/lib/python3.7/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#   Time: 6.68 s, Case: [0.7 0.9], Tol: 0.02000, Max Error: 14573374862868.626953
# Epoch 0
#   train loss: 1.2467e-02, decoder: 1.2058e-02, wsindy-x: 1.3201e-04, wsindy-z: 2.6702e-04, wsindy-reg: 1.0000
# Epoch 100
#   train loss: 3.9877e-03, decoder: 3.0651e-03, wsindy-x: 1.3325e-04, wsindy-z: 7.7939e-04, wsindy-reg: 0.9973
# Epoch 200
#   train loss: 1.8533e-03, decoder: 1.3486e-03, wsindy-x: 1.3225e-04, wsindy-z: 3.6254e-04, wsindy-reg: 0.9958
# Epoch 300
#   train loss: 1.1509e-03, decoder: 7.3859e-04, wsindy-x: 1.3161e-04, wsindy-z: 2.7071e-04, wsindy-reg: 0.9948
# Epoch 400
#   train loss: 8.4935e-04, decoder: 5.3884e-04, wsindy-x: 1.3135e-04, wsindy-z: 1.6923e-04, wsindy-reg: 0.9941
# Epoch 500
#   train loss: 7.0644e-04, decoder: 4.3712e-04, wsindy-x: 1.3134e-04, wsindy-z: 1.2805e-04, wsindy-reg: 0.9936
# Epoch 600
#   train loss: 6.2186e-04, decoder: 3.6678e-04, wsindy-x: 1.3121e-04, wsindy-z: 1.1395e-04, wsindy-reg: 0.9931
# Epoch 700
#   train loss: 5.6002e-04, decoder: 3.2101e-04, wsindy-x: 1.3102e-04, wsindy-z: 9.8067e-05, wsindy-reg: 0.9926
# Epoch 800
#   train loss: 5.1212e-04, decoder: 2.9197e-04, wsindy-x: 1.3082e-04, wsindy-z: 7.9406e-05, wsindy-reg: 0.9921
# Epoch 900
#   train loss: 4.7902e-04, decoder: 2.7264e-04, wsindy-x: 1.3064e-04, wsindy-z: 6.5822e-05, wsindy-reg: 0.9917
# Epoch 1000
#   train loss: 4.5724e-04, decoder: 2.5935e-04, wsindy-x: 1.3043e-04, wsindy-z: 5.7552e-05, wsindy-reg: 0.9913
# Epoch 1100
#   train loss: 4.5365e-04, decoder: 2.4996e-04, wsindy-x: 1.2962e-04, wsindy-z: 6.4163e-05, wsindy-reg: 0.9908
# Epoch 1200
#   train loss: 4.2596e-04, decoder: 2.3974e-04, wsindy-x: 1.2971e-04, wsindy-z: 4.6606e-05, wsindy-reg: 0.9904
# Epoch 1300
#   train loss: 4.1426e-04, decoder: 2.3312e-04, wsindy-x: 1.2961e-04, wsindy-z: 4.1635e-05, wsindy-reg: 0.9900
# Epoch 1400
#   train loss: 4.0543e-04, decoder: 2.2701e-04, wsindy-x: 1.2945e-04, wsindy-z: 3.9068e-05, wsindy-reg: 0.9896
# Epoch 1500
#   train loss: 3.9496e-04, decoder: 2.2104e-04, wsindy-x: 1.2926e-04, wsindy-z: 3.4775e-05, wsindy-reg: 0.9892
# Epoch 1600
#   train loss: 3.8558e-04, decoder: 2.1522e-04, wsindy-x: 1.2909e-04, wsindy-z: 3.1383e-05, wsindy-reg: 0.9888
# Epoch 1700
#   train loss: 3.7730e-04, decoder: 2.0979e-04, wsindy-x: 1.2891e-04, wsindy-z: 2.8709e-05, wsindy-reg: 0.9884
# Epoch 1800
#   train loss: 3.6972e-04, decoder: 2.0476e-04, wsindy-x: 1.2875e-04, wsindy-z: 2.6324e-05, wsindy-reg: 0.9880
# Epoch 1900
#   train loss: 3.6254e-04, decoder: 1.9990e-04, wsindy-x: 1.2859e-04, wsindy-z: 2.4175e-05, wsindy-reg: 0.9876
# Epoch 2000
#   train loss: 3.5584e-04, decoder: 1.9541e-04, wsindy-x: 1.2843e-04, wsindy-z: 2.2126e-05, wsindy-reg: 0.9872
# Epoch 2100
#   train loss: 3.4952e-04, decoder: 1.9116e-04, wsindy-x: 1.2826e-04, wsindy-z: 2.0239e-05, wsindy-reg: 0.9868
# Epoch 2200
#   train loss: 3.5944e-04, decoder: 1.8953e-04, wsindy-x: 1.2794e-04, wsindy-z: 3.2113e-05, wsindy-reg: 0.9863
# Epoch 2300
#   train loss: 3.4727e-04, decoder: 1.8536e-04, wsindy-x: 1.2793e-04, wsindy-z: 2.4119e-05, wsindy-reg: 0.9858
# Epoch 2400
#   train loss: 3.4112e-04, decoder: 1.8217e-04, wsindy-x: 1.2782e-04, wsindy-z: 2.1272e-05, wsindy-reg: 0.9854
# Epoch 2500
#   train loss: 3.3646e-04, decoder: 1.7900e-04, wsindy-x: 1.2771e-04, wsindy-z: 1.9900e-05, wsindy-reg: 0.9850
# Epoch 2600
#   train loss: 3.2924e-04, decoder: 1.7570e-04, wsindy-x: 1.2760e-04, wsindy-z: 1.6100e-05, wsindy-reg: 0.9846
# Epoch 2700
#   train loss: 3.2472e-04, decoder: 1.7284e-04, wsindy-x: 1.2747e-04, wsindy-z: 1.4578e-05, wsindy-reg: 0.9842
# Epoch 2800
#   train loss: 3.2050e-04, decoder: 1.6997e-04, wsindy-x: 1.2734e-04, wsindy-z: 1.3355e-05, wsindy-reg: 0.9838
# Epoch 2900
#   train loss: 3.1596e-04, decoder: 1.6724e-04, wsindy-x: 1.2719e-04, wsindy-z: 1.1706e-05, wsindy-reg: 0.9833
# Epoch 3000
#   train loss: 3.1345e-04, decoder: 1.6458e-04, wsindy-x: 1.2705e-04, wsindy-z: 1.1994e-05, wsindy-reg: 0.9829
# Epoch 3100
#   train loss: 3.1036e-04, decoder: 1.6210e-04, wsindy-x: 1.2690e-04, wsindy-z: 1.1543e-05, wsindy-reg: 0.9825
# Epoch 3200
#   train loss: 3.0703e-04, decoder: 1.5988e-04, wsindy-x: 1.2678e-04, wsindy-z: 1.0547e-05, wsindy-reg: 0.9821
# Epoch 3300
#   train loss: 3.0448e-04, decoder: 1.5772e-04, wsindy-x: 1.2664e-04, wsindy-z: 1.0301e-05, wsindy-reg: 0.9816
# Epoch 3400
#   train loss: 3.0133e-04, decoder: 1.5545e-04, wsindy-x: 1.2650e-04, wsindy-z: 9.5722e-06, wsindy-reg: 0.9812
# Epoch 3500
#   train loss: 2.9895e-04, decoder: 1.5316e-04, wsindy-x: 1.2637e-04, wsindy-z: 9.6097e-06, wsindy-reg: 0.9807
# Epoch 3600
#   train loss: 2.9503e-04, decoder: 1.5122e-04, wsindy-x: 1.2625e-04, wsindy-z: 7.7645e-06, wsindy-reg: 0.9802
# Epoch 3700
#   train loss: 2.9270e-04, decoder: 1.4935e-04, wsindy-x: 1.2611e-04, wsindy-z: 7.4402e-06, wsindy-reg: 0.9797
# Epoch 3800
#   train loss: 2.8986e-04, decoder: 1.4760e-04, wsindy-x: 1.2598e-04, wsindy-z: 6.4938e-06, wsindy-reg: 0.9792
# Epoch 3900
#   train loss: 2.8719e-04, decoder: 1.4593e-04, wsindy-x: 1.2586e-04, wsindy-z: 5.6142e-06, wsindy-reg: 0.9787
# Epoch 4000
#   train loss: 2.8477e-04, decoder: 1.4428e-04, wsindy-x: 1.2572e-04, wsindy-z: 4.9847e-06, wsindy-reg: 0.9782
# Epoch 4100
#   train loss: 2.8236e-04, decoder: 1.4280e-04, wsindy-x: 1.2559e-04, wsindy-z: 4.2000e-06, wsindy-reg: 0.9776
# Epoch 4200
#   train loss: 2.8025e-04, decoder: 1.4119e-04, wsindy-x: 1.2545e-04, wsindy-z: 3.8447e-06, wsindy-reg: 0.9771
# Epoch 4300
#   train loss: 2.7825e-04, decoder: 1.3971e-04, wsindy-x: 1.2532e-04, wsindy-z: 3.4534e-06, wsindy-reg: 0.9765
# Epoch 4400
#   train loss: 2.7653e-04, decoder: 1.3832e-04, wsindy-x: 1.2519e-04, wsindy-z: 3.2566e-06, wsindy-reg: 0.9760
# Epoch 4500
#   train loss: 2.7464e-04, decoder: 1.3696e-04, wsindy-x: 1.2507e-04, wsindy-z: 2.8511e-06, wsindy-reg: 0.9754
# Epoch 4600
#   train loss: 2.7305e-04, decoder: 1.3572e-04, wsindy-x: 1.2494e-04, wsindy-z: 2.6422e-06, wsindy-reg: 0.9748
# Epoch 4700
#   train loss: 2.7186e-04, decoder: 1.3449e-04, wsindy-x: 1.2481e-04, wsindy-z: 2.8205e-06, wsindy-reg: 0.9743
# Epoch 4800
#   train loss: 2.7016e-04, decoder: 1.3333e-04, wsindy-x: 1.2468e-04, wsindy-z: 2.4141e-06, wsindy-reg: 0.9737
# Epoch 4900
#   train loss: 2.6887e-04, decoder: 1.3226e-04, wsindy-x: 1.2458e-04, wsindy-z: 2.3045e-06, wsindy-reg: 0.9731
# Epoch 5000
#   train loss: 2.6718e-04, decoder: 1.3116e-04, wsindy-x: 1.2446e-04, wsindy-z: 1.8351e-06, wsindy-reg: 0.9725
# Epoch 5100
#   train loss: 2.6584e-04, decoder: 1.3016e-04, wsindy-x: 1.2435e-04, wsindy-z: 1.6205e-06, wsindy-reg: 0.9719
# Epoch 5200
#   train loss: 2.6479e-04, decoder: 1.2919e-04, wsindy-x: 1.2427e-04, wsindy-z: 1.6208e-06, wsindy-reg: 0.9712
# Epoch 5300
#   train loss: 2.6347e-04, decoder: 1.2826e-04, wsindy-x: 1.2414e-04, wsindy-z: 1.3660e-06, wsindy-reg: 0.9706
# Epoch 5400
#   train loss: 2.6262e-04, decoder: 1.2736e-04, wsindy-x: 1.2402e-04, wsindy-z: 1.5324e-06, wsindy-reg: 0.9700
# Epoch 5500
#   train loss: 2.6126e-04, decoder: 1.2651e-04, wsindy-x: 1.2391e-04, wsindy-z: 1.1457e-06, wsindy-reg: 0.9694
# Epoch 5600
#   train loss: 2.6040e-04, decoder: 1.2568e-04, wsindy-x: 1.2380e-04, wsindy-z: 1.2288e-06, wsindy-reg: 0.9687
# Epoch 5700
#   train loss: 2.5942e-04, decoder: 1.2490e-04, wsindy-x: 1.2368e-04, wsindy-z: 1.1550e-06, wsindy-reg: 0.9680
# Epoch 5800
#   train loss: 2.5827e-04, decoder: 1.2413e-04, wsindy-x: 1.2356e-04, wsindy-z: 9.0777e-07, wsindy-reg: 0.9673
# Epoch 5900
#   train loss: 2.5736e-04, decoder: 1.2339e-04, wsindy-x: 1.2346e-04, wsindy-z: 8.3978e-07, wsindy-reg: 0.9666
# Epoch 6000
#   train loss: 2.5647e-04, decoder: 1.2267e-04, wsindy-x: 1.2332e-04, wsindy-z: 8.1084e-07, wsindy-reg: 0.9659
# Epoch 6100
#   train loss: 2.5648e-04, decoder: 1.2201e-04, wsindy-x: 1.2318e-04, wsindy-z: 1.6379e-06, wsindy-reg: 0.9652
# Epoch 6200
#   train loss: 2.5479e-04, decoder: 1.2131e-04, wsindy-x: 1.2305e-04, wsindy-z: 7.8882e-07, wsindy-reg: 0.9644
# Epoch 6300
#   train loss: 2.5410e-04, decoder: 1.2064e-04, wsindy-x: 1.2289e-04, wsindy-z: 9.2662e-07, wsindy-reg: 0.9636
# Epoch 6400
#   train loss: 2.5324e-04, decoder: 1.2001e-04, wsindy-x: 1.2274e-04, wsindy-z: 8.5433e-07, wsindy-reg: 0.9628
# Epoch 6500
#   train loss: 2.5226e-04, decoder: 1.1940e-04, wsindy-x: 1.2263e-04, wsindy-z: 6.1415e-07, wsindy-reg: 0.9620
# Epoch 6600
#   train loss: 2.5162e-04, decoder: 1.1883e-04, wsindy-x: 1.2248e-04, wsindy-z: 6.9706e-07, wsindy-reg: 0.9612
# Epoch 6700
#   train loss: 2.5236e-04, decoder: 1.1826e-04, wsindy-x: 1.2235e-04, wsindy-z: 2.1472e-06, wsindy-reg: 0.9603
# Epoch 6800
#   train loss: 2.5008e-04, decoder: 1.1772e-04, wsindy-x: 1.2227e-04, wsindy-z: 5.0001e-07, wsindy-reg: 0.9595
# Epoch 6900
#   train loss: 2.4929e-04, decoder: 1.1719e-04, wsindy-x: 1.2212e-04, wsindy-z: 3.9323e-07, wsindy-reg: 0.9586
# Epoch 7000
#   train loss: 2.4865e-04, decoder: 1.1670e-04, wsindy-x: 1.2199e-04, wsindy-z: 3.7958e-07, wsindy-reg: 0.9577
# Epoch 7100
#   train loss: 2.4829e-04, decoder: 1.1623e-04, wsindy-x: 1.2190e-04, wsindy-z: 5.9454e-07, wsindy-reg: 0.9567
# Epoch 7200
#   train loss: 2.4766e-04, decoder: 1.1580e-04, wsindy-x: 1.2184e-04, wsindy-z: 4.5273e-07, wsindy-reg: 0.9557
# Epoch 7300
#   train loss: 2.4728e-04, decoder: 1.1535e-04, wsindy-x: 1.2168e-04, wsindy-z: 6.9736e-07, wsindy-reg: 0.9547
# Epoch 7400
#   train loss: 2.4733e-04, decoder: 1.1501e-04, wsindy-x: 1.2157e-04, wsindy-z: 1.2154e-06, wsindy-reg: 0.9537
# Epoch 7500
#   train loss: 2.4663e-04, decoder: 1.1453e-04, wsindy-x: 1.2146e-04, wsindy-z: 1.1069e-06, wsindy-reg: 0.9526
# Epoch 7600
#   train loss: 2.4533e-04, decoder: 1.1415e-04, wsindy-x: 1.2135e-04, wsindy-z: 3.1279e-07, wsindy-reg: 0.9515
# Epoch 7700
#   train loss: 2.4486e-04, decoder: 1.1376e-04, wsindy-x: 1.2135e-04, wsindy-z: 2.4411e-07, wsindy-reg: 0.9503
# Epoch 7800
#   train loss: 2.4437e-04, decoder: 1.1340e-04, wsindy-x: 1.2125e-04, wsindy-z: 2.2497e-07, wsindy-reg: 0.9491
# Epoch 7900
#   train loss: 2.4425e-04, decoder: 1.1306e-04, wsindy-x: 1.2105e-04, wsindy-z: 6.6457e-07, wsindy-reg: 0.9479
# Epoch 8000
#   train loss: 2.4345e-04, decoder: 1.1274e-04, wsindy-x: 1.2094e-04, wsindy-z: 3.0277e-07, wsindy-reg: 0.9466
# Epoch 8100
#   train loss: 2.4330e-04, decoder: 1.1238e-04, wsindy-x: 1.2086e-04, wsindy-z: 6.0251e-07, wsindy-reg: 0.9453
# Epoch 8200
#   train loss: 2.4245e-04, decoder: 1.1207e-04, wsindy-x: 1.2073e-04, wsindy-z: 2.0191e-07, wsindy-reg: 0.9439
# Epoch 8300
#   train loss: 2.4200e-04, decoder: 1.1176e-04, wsindy-x: 1.2062e-04, wsindy-z: 1.9037e-07, wsindy-reg: 0.9425
# Epoch 8400
#   train loss: 2.4210e-04, decoder: 1.1151e-04, wsindy-x: 1.2072e-04, wsindy-z: 4.6129e-07, wsindy-reg: 0.9411
# Epoch 8500
#   train loss: 2.4115e-04, decoder: 1.1117e-04, wsindy-x: 1.2042e-04, wsindy-z: 1.7080e-07, wsindy-reg: 0.9396
# Epoch 8600
#   train loss: 2.4082e-04, decoder: 1.1092e-04, wsindy-x: 1.2026e-04, wsindy-z: 2.5607e-07, wsindy-reg: 0.9380
# Epoch 8700
#   train loss: 2.4038e-04, decoder: 1.1065e-04, wsindy-x: 1.2020e-04, wsindy-z: 1.7748e-07, wsindy-reg: 0.9364
# Epoch 8800
#   train loss: 2.3986e-04, decoder: 1.1038e-04, wsindy-x: 1.1999e-04, wsindy-z: 1.3841e-07, wsindy-reg: 0.9348
# Epoch 8900
#   train loss: 2.3959e-04, decoder: 1.1011e-04, wsindy-x: 1.2002e-04, wsindy-z: 1.3383e-07, wsindy-reg: 0.9330
# Epoch 9000
#   train loss: 2.3928e-04, decoder: 1.0988e-04, wsindy-x: 1.1988e-04, wsindy-z: 2.0966e-07, wsindy-reg: 0.9312
# Epoch 9100
#   train loss: 2.3887e-04, decoder: 1.0964e-04, wsindy-x: 1.1978e-04, wsindy-z: 1.5629e-07, wsindy-reg: 0.9294
# Epoch 9200
#   train loss: 2.3849e-04, decoder: 1.0941e-04, wsindy-x: 1.1965e-04, wsindy-z: 1.5375e-07, wsindy-reg: 0.9275
# Epoch 9300
#   train loss: 2.3796e-04, decoder: 1.0917e-04, wsindy-x: 1.1944e-04, wsindy-z: 9.9467e-08, wsindy-reg: 0.9256
# Epoch 9400
#   train loss: 2.3774e-04, decoder: 1.0896e-04, wsindy-x: 1.1926e-04, wsindy-z: 2.8795e-07, wsindy-reg: 0.9235
# Epoch 9500
#   train loss: 2.3738e-04, decoder: 1.0875e-04, wsindy-x: 1.1927e-04, wsindy-z: 1.4081e-07, wsindy-reg: 0.9214
# Epoch 9600
#   train loss: 2.3700e-04, decoder: 1.0856e-04, wsindy-x: 1.1915e-04, wsindy-z: 9.8858e-08, wsindy-reg: 0.9193
# Epoch 9700
#   train loss: 2.3682e-04, decoder: 1.0836e-04, wsindy-x: 1.1903e-04, wsindy-z: 2.6066e-07, wsindy-reg: 0.9170
# Epoch 9800
#   train loss: 2.3620e-04, decoder: 1.0813e-04, wsindy-x: 1.1880e-04, wsindy-z: 1.2418e-07, wsindy-reg: 0.9148
# Epoch 9900
#   train loss: 2.3590e-04, decoder: 1.0792e-04, wsindy-x: 1.1876e-04, wsindy-z: 9.3330e-08, wsindy-reg: 0.9124
# * Evaluating
#   Time: 2.53 s, Case: [0.7 0.9], Tol: 0.02000, Max Error: 0.147308
#   Max rel. err.: 47.8%, Update tolerance for error indicator from 0.02000 to 0.22073
#   PARAMETERS EXIST, NOT adding it! idx: 0 param: [0.7 0.9]
#   Max error indicator <= Tol! Current subset ratio 0.0%
# training time: 3.13 mins, 0.05 hours

# %%
# history of validation loss
train_loss = np.array(df['training_losses'][0]).squeeze()
test_loss = np.array(df['testing_losses'][0]).squeeze()

fig, ax1 = plt.subplots(figsize=(9,5))
xt = np.linspace(1,df['epoch_count'],train_loss.shape[0])
ax1.plot(xt, train_loss[:,0], 'r', label='Train')
ax1.set_yscale('log')
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
ax1.set_xlabel('Epochs', fontsize=16)
ax1.set_ylabel('Loss', color='r', fontsize=16)
ax1.set_xlim(0, params['epoch_count'])
ax1.tick_params(axis='x', labelsize=14)
ax1.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
xt = np.linspace(1,df['epoch_count'],test_loss.shape[0])
ax2.plot(xt, test_loss, 'b-o', label='Val')
ax2.set_ylabel('Max Error', color='b', fontsize=16)
ax2.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='y', labelcolor='b')

plt.grid()
plt.tight_layout()
plt.savefig(f"{params['fig_path']}/loss.png")
